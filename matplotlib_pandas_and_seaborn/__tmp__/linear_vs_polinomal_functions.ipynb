# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x = np.arange(1,10)
y = x**3 +2*x + 0

plt.plot(x,y)
plt.plot([0,5],[0,140], c='green')
plt.plot([5, 9],[140, 500], c='green')
plt.scatter(5,140, c="red")
