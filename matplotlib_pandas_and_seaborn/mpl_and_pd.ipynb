# %%
# %matplotlib inline 

import matplotlib.pyplot as plt
import matplotlib.cm as cm
import numpy as np
import pandas as pd

# %%
drinks = pd.read_csv("../datasets/drinks.csv")
drinks.head(3)
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF

# %%
drinks.isnull().sum()
# Out:
# country                          0
# beer_servings                    0
# spirit_servings                  0
# wine_servings                    0
# total_litres_of_pure_alcohol     0
# continent                       23
# dtype: int64

# %%
cont_count= df["continent"].value_counts()
cont_count

cont_count.plot(kind='bar', title='Countries per Continent')
plt.xlabel('Continent')
plt.ylabel('Count')
plt.show()

# %%
# bar plot average number of wine servings per continent
wine_ser = df.groupby(['continent', 'wine_servings'])["wine_servings"].max()
wine_ser.sort_values(ascending=False).plot(kind='bar', title='average number of wine servings per continent')

# %%
# histogram of wine servings in france
fr_s = df["wine_servings"]
fr_s
fr_s.plot.hist(bins=20, rwidth=0.9,color='#607c8e')
plt.xlabel('Counts')
plt.ylabel('Servings')
plt.grid(axis='y')

# %%
# scatterplot of beer servings versus wine servings (colored EU vs USA)
colors_eu = np.where(df.continent=='EU', 'red', 'black')
# colors_usa = np.where(df.country=="USA", 'lightgreen', 'black')


df.plot(x='beer_servings', y='wine_servings', kind='scatter', color=colors_eu)

# %%
df1 = pd.DataFrame({"a":np.array([1,None,3]), "b":np.array([1,None,None])})
df1.head(3)
# Out:
#       a     b
# 0     1     1
# 1  None  None
# 2     3  None

# %%
df1.isnull().sum()
# Out:
# a    1
# b    2
# dtype: int64
