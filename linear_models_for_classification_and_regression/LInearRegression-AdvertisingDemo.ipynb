# %%
import numpy as np
import pandas as pd

from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Load the data

# %%
df = pd.read_csv("../datasets/Advertising/Advertising.csv",index_col=0)

# %%
df.head()
# Out:
#       TV  radio  newspaper  sales
# 1  230.1   37.8       69.2   22.1
# 2   44.5   39.3       45.1   10.4
# 3   17.2   45.9       69.3    9.3
# 4  151.5   41.3       58.5   18.5
# 5  180.8   10.8       58.4   12.9

# %%
sns.heatmap(df.corr(),cmap="Reds",annot=True)

# %% [markdown]
# ### Scaterplot

# %%
sns.set(style="ticks", color_codes=True)
sns.pairplot(df, 
             x_vars=['TV','radio','newspaper'],              
             y_vars='sales',
             palette=sns.hls_palette(6, l=.6, s=.8),             
             markers=["o"],
             plot_kws={
                 'line_kws':{'color':'#FFAAAA'},
                       
                 'scatter_kws':{'facecolors':'#AAFFAA'}},
             size=5, 
             aspect=1,
             kind='reg'
             )

# %% [markdown]
# ## Clean the data

# %%
df.isnull().sum()
# Out:
# TV           0
# radio        0
# newspaper    0
# sales        0
# dtype: int64

# %% [markdown]
# # Choose the features

# %%
X = df[['TV', 'newspaper', 'radio']]
y = df[['sales']]

# %%
(X_train, X_test, y_train, y_test) = train_test_split(X, y, random_state=42)

# %% [markdown]
# # Train (fit) the model

# %%
lm = LinearRegression().fit(X_train,y_train)

# %% [markdown]
# # Predict
#
#
# tv: 22.000
# radio: 5.000
# neespaper: 10.000
#
# sales = ?

# %%
X_train.head(1)
# Out:
#        TV  newspaper  radio
# 115  78.2       34.5   46.8

# %%
y_pred = lm.predict(X_test)

# %% [markdown]
# # Score

# %%
from sklearn import metrics

# %%
print('MAE: ', metrics.mean_absolute_error(y_test, y_pred))
print('MSE: ', metrics.mean_squared_error(y_test, y_pred))
print('RMSE: ', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))


print('score', lm.score(X_train, y_train)) 
print('score', lm.score(X_test, y_train))
# Out:
# MAE:  1.4023124989385067
# MSE:  2.880023730094192
# RMSE:  1.6970632663793628
# score 0.8966445527601499
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-72-3bdea4c745d0> in <module>
#       5
#       6 print('score', lm.score(X_train, y_train))
# ----> 7 print('score', lm.score(X_test, y_train))
#
# ~/projects/courses/ProgressBG/ProgressBG-MLwithPython/ProgressBG-MLwithPython-Code/.venv/lib/python3.7/site-packages/sklearn/base.py in score(self, X, y, sample_weight)
#     327         from .metrics import r2_score
#     328         return r2_score(y, self.predict(X), sample_weight=sample_weight,
# --> 329                         multioutput='variance_weighted')
#     330
#     331
#
# ...
