# %%
import pandas as pd

# %%
#Get DataFrame from JSON file:
df = pd.read_json("pythonbooks.revolunet.com.issues.json")
df
# Out:
#                               author  \
# 0                        Mike Pirnat
# 1                        David Mertz
# 2                        David Mertz
# 3                Luiz Eduardo Borges
# 4                    Muhammad Yasoob
# 5               B. Miller & D. Ranum
# 6                  Jeffrey Elkner...
# 7               B. Miller & D. Ranum
# 8                        Zed A. Shaw
# 9                       Mark Pilgrim
# 10                      Mark Pilgrim
# 11                   Allen B. Downey
# 12                              Kivy
# 13                         Community
# 14                         Community
# 15                    Armin Ronacher
# 16                       Al Sweigart
# 17                       Ian Ozsvald
# 18                       Swaroop C H
# 19                      Dave Kuhlman
# 20                     Fredrik Lundh
# 21                   Jason R. Briggs
# 22                    Jan Erik Solem
# 23              S. Bird, E. Klein...
# ...

# %%
# fileter rows with "level" == "Advanced"
df_rf = df[df['level']=="Advanced"]
df_rf
# Out:
#                   author                                          authorUrl  \
# 17           Ian Ozsvald  http://ianozsvald.com/2011/07/25/high-performa...
# 22        Jan Erik Solem                       http://www.janeriksolem.net/
# 23  S. Bird, E. Klein...                               http://www.nltk.org/
# 24       Allen B. Downey                      http://www.greenteapress.com/
# 25       Allen B. Downey                      http://www.greenteapress.com/
# 26       Allen B. Downey                      http://www.greenteapress.com/
# 73     Massimo Di Pierro                      https://twitter.com/mdipierro
# 76           John Hearty  https://www.packtpub.com/packt/free-ebook/adva...
#
#                                             cover  \
# 17                         img/cover_highperf.png
# 22                   img/cover_computervision.jpg
# 23                             img/cover_nltk.jpg
# 24                       img/cover_complexity.jpg
# ...

# %%
# create new DF, with selected columns
df_cf = df_rf[['author', 'title','url','level']]
df_cf
# Out:
#                   author                                    title  \
# 17           Ian Ozsvald         High Performance Python tutorial
# 22        Jan Erik Solem  Programming Computer Vision with Python
# 23  S. Bird, E. Klein...  Natural Language Processing with Python
# 24       Allen B. Downey                         Think Complexity
# 25       Allen B. Downey                              Think Stats
# 26       Allen B. Downey                           Think Stats 2e
# 73     Massimo Di Pierro           Annotated Algorithms In Python
# 76           John Hearty    Advanced Machine Learning with Python
#
#                                                   url     level
# 17  http://ianozsvald.com/HighPerformancePythonfro...  Advanced
# 22  http://programmingcomputervision.com/downloads...  Advanced
# 23                          http://www.nltk.org/book/  Advanced
# 24  http://www.greenteapress.com/complexity/thinkc...  Advanced
# ...
