# %% [markdown]
# # DataFrames Join

# %%
import pandas as pd

# %% [markdown]
# ## Load data  - not good for join!!!

# %%
devs = pd.read_csv("datasets/developers/developers.csv", sep=";")
devs
# Out:
#    did        dname
# 0    1         Ivan
# 1    2         Asen
# 2    3        Maria
# 3    4       Stoyan
# 4    5        Aleks
# 5    6      Svetlin

# %%
langs = pd.read_csv("datasets/developers/languages.csv", sep=";")
langs
# Out:
#    did      language
# 0    2         "C++"
# 1    3      "Python"
# 2    3           "R"
# 3    6        "Java"

# %% [markdown]
# ## Load data  -  good for join!!!

# %%
bg_towns = pd.DataFrame(["sofia", "sandanski", "pleven","varna"], columns=["town"])
bg_towns
# Out:
#         town
# 0      sofia
# 1  sandanski
# 2     pleven
# 3      varna

# %%
bg_weather = pd.DataFrame([25, 35, 20 ], columns=["temp"])
bg_weather
# Out:
#    temp
# 0    25
# 1    35
# 2    20

# %% [markdown]
# ## Inner Join with Join()

# %%
# on="did" => matches devs.did == langs.index 
# how="inner" => removes NaN value

dev_langs_inner = devs.join(langs,lsuffix="_l",rsuffix="_r", on="dname", how="inner")
dev_langs_inner
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /data/projects/www/wwwcourses.github.io/ProgressBG-VC2-Python/.venv/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'dname'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-610b83bba7fd> in <module>()
#       2 # how="inner" => removes NaN value
#       3
# ----> 4 dev_langs_inner = devs.join(langs,lsuffix="_l",rsuffix="_r", on="dname", how="inner")
#       5 dev_langs_inner
#
# /data/projects/www/wwwcourses.github.io/ProgressBG-VC2-Python/.venv/lib/python3.6/site-packages/pandas/core/frame.py in join(self, other, on, how, lsuffix, rsuffix, sort)
#    5314         # For SparseDataFrame's benefit
#    5315         return self._join_compat(other, on=on, how=how, lsuffix=lsuffix,
# -> 5316                                  rsuffix=rsuffix, sort=sort)
#    5317
#    5318     def _join_compat(self, other, on=None, how='left', lsuffix='', rsuffix='',
#
# /data/projects/www/wwwcourses.github.io/ProgressBG-VC2-Python/.venv/lib/python3.6/site-packages/pandas/core/frame.py in _join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    5329             return merge(self, other, left_on=on, how=how,
#    5330                          left_index=on is None, right_index=True,
# -> 5331                          suffixes=(lsuffix, rsuffix), sort=sort)
#    5332         else:
#    5333             if on is not None:
#
# /data/projects/www/wwwcourses.github.io/ProgressBG-VC2-Python/.venv/lib/python3.6/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      55                          right_index=right_index, sort=sort, suffixes=suffixes,
#      56                          copy=copy, indicator=indicator,
# ---> 57                          validate=validate)
#      58     return op.get_result()
#      59
#
# /data/projects/www/wwwcourses.github.io/ProgressBG-VC2-Python/.venv/lib/python3.6/site-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     563         (self.left_join_keys,
#     564          self.right_join_keys,
# --> 565          self.join_names) = self._get_merge_keys()
#     566
#     567         # validate the merge keys dtypes. We may need to coerce
#
# /data/projects/www/wwwcourses.github.io/ProgressBG-VC2-Python/.venv/lib/python3.6/site-packages/pandas/core/reshape/merge.py in _get_merge_keys(self)
#     847                     join_names.append(None)
#     848                 else:
# --> 849                     left_keys.append(left[k]._values)
#     850                     join_names.append(k)
#     851             if isinstance(self.right.index, MultiIndex):
#
# /data/projects/www/wwwcourses.github.io/ProgressBG-VC2-Python/.venv/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2137             return self._getitem_multilevel(key)
#    2138         else:
# -> 2139             return self._getitem_column(key)
#    2140
#    2141     def _getitem_column(self, key):
#
# /data/projects/www/wwwcourses.github.io/ProgressBG-VC2-Python/.venv/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2144         # get column
#    2145         if self.columns.is_unique:
# -> 2146             return self._get_item_cache(key)
#    2147
#    2148         # duplicate columns & possible reduce dimensionality
#
# /data/projects/www/wwwcourses.github.io/ProgressBG-VC2-Python/.venv/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1840         res = cache.get(item)
#    1841         if res is None:
# -> 1842             values = self._data.get(item)
#    1843             res = self._box_item_values(item, values)
#    1844             cache[item] = res
#
# /data/projects/www/wwwcourses.github.io/ProgressBG-VC2-Python/.venv/lib/python3.6/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3841
#    3842             if not isna(item):
# -> 3843                 loc = self.items.get_loc(item)
#    3844             else:
#    3845                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# /data/projects/www/wwwcourses.github.io/ProgressBG-VC2-Python/.venv/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
# -> 2527                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2528
#    2529         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'dname'

# %%
bg_weather_inner = bg_weather.join(bg_towns, how="inner")
bg_weather_inner

# %% [markdown]
# ## Outer Join with Join()

# %%
dev_langs_outer = devs.join(langs,lsuffix="_l",rsuffix="_r", on="did", how="outer")
dev_langs_outer

# %%
bg_weather_outer = bg_weather.join(bg_towns, how="outer")
bg_weather_outer
